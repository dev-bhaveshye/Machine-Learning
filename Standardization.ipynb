# %% [markdown]
# <a href="https://colab.research.google.com/github/dev-bhaveshye/Machine-Learning/blob/main/Standardization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('/content/Salary_dataset (1).csv')
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df=df.loc[:, ['YearsExperience', 'Salary']]
df
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
sns.scatterplot(data=df, x='YearsExperience', y='Salary')
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
# !pip install scikit-learn

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(df)
scaled_data = scaler.transform(df)
scaled_data
# Out:
# array([[-1.51005294, -1.36011263],
#        [-1.43837321, -1.10552744],
#        [-1.36669348, -1.419919  ],
#        [-1.18749416, -1.20495739],
#        [-1.11581443, -1.33978143],
#        [-0.86493538, -0.71830716],
#        [-0.82909552, -0.58815781],
#        [-0.75741579, -0.79981746],
#        [-0.75741579, -0.42881019],
#        [-0.57821647, -0.69801306],
#        [-0.50653674, -0.47433279],
#        [-0.47069688, -0.74976858],
#        [-0.47069688, -0.70662043],
#        [-0.43485702, -0.70201994],
#        [-0.29149756, -0.55250402],
#        [-0.1481381 , -0.29921736],
#        [-0.07645838, -0.37004264],
#        [-0.00477865,  0.26285865],
#        [ 0.21026054,  0.19885989],
#        [ 0.2461004 ,  0.66547573],
#        [ 0.53281931,  0.58377993],
#        [ 0.6403389 ,  0.82623317],
#        [ 0.92705781,  0.93861127],
#        [ 1.03457741,  1.40274136],
#        [ 1.21377673,  1.24020308],
#        [ 1.32129632,  1.09740238],
#        [ 1.50049564,  1.51986835],
# ...

# %%
df=pd.DataFrame(scaled_data, columns=['YearsExperience', 'Salary'])
df
# Out:
#     YearsExperience    Salary
# 0         -1.510053 -1.360113
# 1         -1.438373 -1.105527
# 2         -1.366693 -1.419919
# 3         -1.187494 -1.204957
# 4         -1.115814 -1.339781
# 5         -0.864935 -0.718307
# 6         -0.829096 -0.588158
# 7         -0.757416 -0.799817
# 8         -0.757416 -0.428810
# 9         -0.578216 -0.698013
# 10        -0.506537 -0.474333
# 11        -0.470697 -0.749769
# 12        -0.470697 -0.706620
# 13        -0.434857 -0.702020
# 14        -0.291498 -0.552504
# 15        -0.148138 -0.299217
# 16        -0.076458 -0.370043
# 17        -0.004779  0.262859
# 18         0.210261  0.198860
# 19         0.246100  0.665476
# 20         0.532819  0.583780
# 21         0.640339  0.826233
# 22         0.927058  0.938611
# 23         1.034577  1.402741
# 24         1.213777  1.240203
# 25         1.321296  1.097402
# 26         1.500496  1.519868
# 27         1.536336  1.359074
# 28         1.787215  1.721028
# 29         1.858894  1.701773

# %%
x=df.iloc[:,0:1]
y=df.iloc[:,-1]
x
# Out:
#     YearsExperience
# 0         -1.510053
# 1         -1.438373
# 2         -1.366693
# 3         -1.187494
# 4         -1.115814
# 5         -0.864935
# 6         -0.829096
# 7         -0.757416
# 8         -0.757416
# 9         -0.578216
# 10        -0.506537
# 11        -0.470697
# 12        -0.470697
# 13        -0.434857
# 14        -0.291498
# 15        -0.148138
# 16        -0.076458
# 17        -0.004779
# 18         0.210261
# 19         0.246100
# 20         0.532819
# 21         0.640339
# 22         0.927058
# 23         1.034577
# 24         1.213777
# 25         1.321296
# 26         1.500496
# 27         1.536336
# 28         1.787215
# 29         1.858894

# %%
y
# Out:
# 0    -1.360113
# 1    -1.105527
# 2    -1.419919
# 3    -1.204957
# 4    -1.339781
# 5    -0.718307
# 6    -0.588158
# 7    -0.799817
# 8    -0.428810
# 9    -0.698013
# 10   -0.474333
# 11   -0.749769
# 12   -0.706620
# 13   -0.702020
# 14   -0.552504
# 15   -0.299217
# 16   -0.370043
# 17    0.262859
# 18    0.198860
# 19    0.665476
# 20    0.583780
# 21    0.826233
# 22    0.938611
# 23    1.402741
# 24    1.240203
# 25    1.097402
# 26    1.519868
# 27    1.359074
# 28    1.721028
# 29    1.701773
# Name: Salary, dtype: float64

# %%
x_train , x_test , y_train , y_test =train_test_split(x,y,test_size=0.1)

# %%
from sklearn.linear_model import LinearRegression
linear_model=LinearRegression()
linear_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
linear_model.predict(x_test)
# Out:
# array([ 0.19088237,  0.22576065, -1.16937046])

# %%
y_test
# Out:
# 18    0.198860
# 19    0.665476
# 3    -1.204957
# Name: Salary, dtype: float64

# %%
linear_model.score(x_test,y_test)
# Out:
# 0.8973020848798644
