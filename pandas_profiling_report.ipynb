# %% [markdown]
# <a href="https://colab.research.google.com/github/dev-bhaveshye/Machine-Learning/blob/main/pandas_profiling_report.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -profiling

# %%
import seaborn as sns
titanic=sns.load_dataset('titanic')

# %%
from ydata_profiling import ProfileReport
prof=ProfileReport(titanic)
prof.to_file('report_titanic')
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/ydata_profiling/profile_report.py:379: UserWarning: Extension  not supported. For now we assume .html was intended. To remove this warning, please use .html or .json.
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
